# %% [markdown]
# # Health Stats Part 3: Waist 2 Hip Ratios

# %% [markdown]
# <!--- Write an explanation of the Waist To Hips Ratio statistic used by health professionals. Please include an explanation of what it is used for, exactly how it is calculated, and how to interpret the results. Note: Formmatting matters. Make this as professional as you can using Markdown.  --->
# EDIT THIS MARKDOWN CELL

# %% [markdown]
# ## Source Data

# %% [markdown]
# <!--- Replace the text below with a Markdown bullet list that defines the columns of the CSV file. Be sure to indicate the data type for each column. --->
# EDIT THIS MARKDOWN CELL

# %% [markdown]
# ## Data Import

# %%
# Goal: Extract the data from the file

import numpy as np
import pandas as pd


data = pd.read_csv(("w2h_data.csv"), dtype = {"ID": np.int, "Waist": np.float, "Hip": np.float, "Gender": np.str})
print(data)
# Out:
#     ID  Waist   Hip Gender
# 0    1   30.0  32.0      M
# 1    2   32.0  37.0      M
# 2    3   30.0  36.0      M
# 3    4   33.0  39.0      M
# 4    5   29.0  33.0      M
# 5    6   32.0  38.0      M
# 6    7   33.0  42.0      M
# 7    8   30.0  40.0      M
# 8    9   30.0  37.0      M
# 9   10   32.0  39.0      M
# 10  11   24.0  35.0      F
# 11  12   25.0  37.0      F
# 12  13   24.0  37.0      F
# 13  14   22.0  34.0      F
# 14  15   26.0  38.0      F
# 15  16   26.0  37.0      F
# 16  17   25.0  38.0      F
# 17  18   26.0  37.0      F
# 18  19   28.0  40.0      F
# 19  20   23.0  35.0      F

# %% [markdown]
# ## Calculations

# %%
##Calculations, based on DataFrame

#calculated the w2h_ratios, using the determined formula
w2h_ratios = data['Waist']/data['Hip']
print(w2h_ratios)

#Added in the w2h_Ratio column
data['w2h_ratios'] = pd.Series(w2h_ratios)
#print(data)

#Now, we'll try to create a column that calculates shape.

# determine who is male (True) or female (False)
males = (data['Gender']=='M')

# males with w2h ration > 0.9 are apple shaped
male_apples = np.logical_and((w2h_ratios>0.9),males)

# females with w2h ratio > 0.8 are apple shaped
female_apples = np.logical_and((w2h_ratios>0.8),np.logical_not(males))

# combines the male_apples and female_apples
apples=np.logical_or(male_apples,female_apples)

# works like an if then else statement
shapes=np.where(apples,'Apple','Pear')

#Now we add and print it...
data['Shape'] = pd.Series(shapes)
print(data)

#Now we'll make it pretty...
data.style
# Out:
# 0     0.937500
# 1     0.864865
# 2     0.833333
# 3     0.846154
# 4     0.878788
# 5     0.842105
# 6     0.785714
# 7     0.750000
# 8     0.810811
# 9     0.820513
# 10    0.685714
# 11    0.675676
# 12    0.648649
# 13    0.647059
# 14    0.684211
# 15    0.702703
# 16    0.657895
# 17    0.702703
# 18    0.700000
# 19    0.657143
# dtype: float64
#     ID  Waist   Hip Gender  w2h_ratios  Shape
# 0    1   30.0  32.0      M    0.937500  Apple
# 1    2   32.0  37.0      M    0.864865   Pear
# 2    3   30.0  36.0      M    0.833333   Pear
# 3    4   33.0  39.0      M    0.846154   Pear
# 4    5   29.0  33.0      M    0.878788   Pear
# 5    6   32.0  38.0      M    0.842105   Pear
# 6    7   33.0  42.0      M    0.785714   Pear
# 7    8   30.0  40.0      M    0.750000   Pear
# 8    9   30.0  37.0      M    0.810811   Pear
# 9   10   32.0  39.0      M    0.820513   Pear
# 10  11   24.0  35.0      F    0.685714   Pear
# 11  12   25.0  37.0      F    0.675676   Pear
# 12  13   24.0  37.0      F    0.648649   Pear
# 13  14   22.0  34.0      F    0.647059   Pear
# 14  15   26.0  38.0      F    0.684211   Pear
# 15  16   26.0  37.0      F    0.702703   Pear
# 16  17   25.0  38.0      F    0.657895   Pear
# 17  18   26.0  37.0      F    0.702703   Pear
# 18  19   28.0  40.0      F    0.700000   Pear
# 19  20   23.0  35.0      F    0.657143   Pear
# <style  type="text/css" >
# </style>
# <table id="T_ff9602fa_a090_11e7_9405_680715b276ee" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >ID</th>
#         <th class="col_heading level0 col1" >Waist</th>
#         <th class="col_heading level0 col2" >Hip</th>
#         <th class="col_heading level0 col3" >Gender</th>
#         <th class="col_heading level0 col4" >w2h_ratios</th>
#         <th class="col_heading level0 col5" >Shape</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ff9602fa_a090_11e7_9405_680715b276ee" class="row_heading level0 row0" >0</th>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow0_col0" class="data row0 col0" >1</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow0_col1" class="data row0 col1" >30</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow0_col2" class="data row0 col2" >32</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow0_col3" class="data row0 col3" >M</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow0_col4" class="data row0 col4" >0.9375</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow0_col5" class="data row0 col5" >Apple</td>
#     </tr>    <tr>
#         <th id="T_ff9602fa_a090_11e7_9405_680715b276ee" class="row_heading level0 row1" >1</th>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow1_col0" class="data row1 col0" >2</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow1_col1" class="data row1 col1" >32</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow1_col2" class="data row1 col2" >37</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow1_col3" class="data row1 col3" >M</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow1_col4" class="data row1 col4" >0.864865</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow1_col5" class="data row1 col5" >Pear</td>
#     </tr>    <tr>
#         <th id="T_ff9602fa_a090_11e7_9405_680715b276ee" class="row_heading level0 row2" >2</th>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow2_col0" class="data row2 col0" >3</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow2_col1" class="data row2 col1" >30</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow2_col2" class="data row2 col2" >36</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow2_col3" class="data row2 col3" >M</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow2_col4" class="data row2 col4" >0.833333</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow2_col5" class="data row2 col5" >Pear</td>
#     </tr>    <tr>
#         <th id="T_ff9602fa_a090_11e7_9405_680715b276ee" class="row_heading level0 row3" >3</th>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow3_col0" class="data row3 col0" >4</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow3_col1" class="data row3 col1" >33</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow3_col2" class="data row3 col2" >39</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow3_col3" class="data row3 col3" >M</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow3_col4" class="data row3 col4" >0.846154</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow3_col5" class="data row3 col5" >Pear</td>
#     </tr>    <tr>
#         <th id="T_ff9602fa_a090_11e7_9405_680715b276ee" class="row_heading level0 row4" >4</th>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow4_col0" class="data row4 col0" >5</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow4_col1" class="data row4 col1" >29</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow4_col2" class="data row4 col2" >33</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow4_col3" class="data row4 col3" >M</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow4_col4" class="data row4 col4" >0.878788</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow4_col5" class="data row4 col5" >Pear</td>
#     </tr>    <tr>
#         <th id="T_ff9602fa_a090_11e7_9405_680715b276ee" class="row_heading level0 row5" >5</th>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow5_col0" class="data row5 col0" >6</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow5_col1" class="data row5 col1" >32</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow5_col2" class="data row5 col2" >38</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow5_col3" class="data row5 col3" >M</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow5_col4" class="data row5 col4" >0.842105</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow5_col5" class="data row5 col5" >Pear</td>
#     </tr>    <tr>
#         <th id="T_ff9602fa_a090_11e7_9405_680715b276ee" class="row_heading level0 row6" >6</th>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow6_col0" class="data row6 col0" >7</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow6_col1" class="data row6 col1" >33</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow6_col2" class="data row6 col2" >42</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow6_col3" class="data row6 col3" >M</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow6_col4" class="data row6 col4" >0.785714</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow6_col5" class="data row6 col5" >Pear</td>
#     </tr>    <tr>
#         <th id="T_ff9602fa_a090_11e7_9405_680715b276ee" class="row_heading level0 row7" >7</th>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow7_col0" class="data row7 col0" >8</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow7_col1" class="data row7 col1" >30</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow7_col2" class="data row7 col2" >40</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow7_col3" class="data row7 col3" >M</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow7_col4" class="data row7 col4" >0.75</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow7_col5" class="data row7 col5" >Pear</td>
#     </tr>    <tr>
#         <th id="T_ff9602fa_a090_11e7_9405_680715b276ee" class="row_heading level0 row8" >8</th>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow8_col0" class="data row8 col0" >9</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow8_col1" class="data row8 col1" >30</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow8_col2" class="data row8 col2" >37</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow8_col3" class="data row8 col3" >M</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow8_col4" class="data row8 col4" >0.810811</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow8_col5" class="data row8 col5" >Pear</td>
#     </tr>    <tr>
#         <th id="T_ff9602fa_a090_11e7_9405_680715b276ee" class="row_heading level0 row9" >9</th>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow9_col0" class="data row9 col0" >10</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow9_col1" class="data row9 col1" >32</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow9_col2" class="data row9 col2" >39</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow9_col3" class="data row9 col3" >M</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow9_col4" class="data row9 col4" >0.820513</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow9_col5" class="data row9 col5" >Pear</td>
#     </tr>    <tr>
#         <th id="T_ff9602fa_a090_11e7_9405_680715b276ee" class="row_heading level0 row10" >10</th>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow10_col0" class="data row10 col0" >11</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow10_col1" class="data row10 col1" >24</td>
#         <td id="T_ff9602fa_a090_11e7_9405_680715b276eerow10_col2" class="data

# %%
# Goal: Create a new array and name it data_recarray.
data_recarray = data.to_records()
print(data_recarray)

# Goal: For each row of data calculate and store the w2h_ratio and shape.
w2h_ratios = data_recarray['Waist']/data_recarray['Hip']
#print(w2h_ratios)

# determine who is male (True) or female (False)
males = (data_recarray['Gender']=='M')

# males with w2h ration > 0.9 are apple shaped
male_apples = np.logical_and((w2h_ratios>0.9),males)

# females with w2h ratio > 0.8 are apple shaped
female_apples = np.logical_and((w2h_ratios>0.8),np.logical_not(males))

# combines the male_apples and female_apples
apples=np.logical_or(male_apples,female_apples)

# works like an if then else statement
shapes=np.where(apples,'Apple','Pear')

# The code below creates a new results array 

# add the two new columns to the dtype descriptor
dt = np.dtype(data_recarray.dtype.descr + [('W2H Ratio',float),('Shape','U5')])

# create a new results array with the same number of data_recarray and the new dtype
results = np.zeros(data_recarray.shape,dtype=dt)

## copy over the data_recarray data
for c in data_recarray.dtype.names:
    results[c]=data_recarray[c]
    
# add the two new columns
results['W2H Ratio']=w2h_ratios
results['Shape']=shapes

# Now, we show the data! (In a variety of formats.)
newdata = pd.DataFrame(results)
#print(newdata)
newdata.style
newdata.to_html("StatsResults.html")
newdata.to_csv("StatsResults.csv")
# Out:
# [( 0,  1,  30.,  32., 'M',  0.9375    , 'Apple')
#  ( 1,  2,  32.,  37., 'M',  0.86486486, 'Pear')
#  ( 2,  3,  30.,  36., 'M',  0.83333333, 'Pear')
#  ( 3,  4,  33.,  39., 'M',  0.84615385, 'Pear')
#  ( 4,  5,  29.,  33., 'M',  0.87878788, 'Pear')
#  ( 5,  6,  32.,  38., 'M',  0.84210526, 'Pear')
#  ( 6,  7,  33.,  42., 'M',  0.78571429, 'Pear')
#  ( 7,  8,  30.,  40., 'M',  0.75      , 'Pear')
#  ( 8,  9,  30.,  37., 'M',  0.81081081, 'Pear')
#  ( 9, 10,  32.,  39., 'M',  0.82051282, 'Pear')
#  (10, 11,  24.,  35., 'F',  0.68571429, 'Pear')
#  (11, 12,  25.,  37., 'F',  0.67567568, 'Pear')
#  (12, 13,  24.,  37., 'F',  0.64864865, 'Pear')
#  (13, 14,  22.,  34., 'F',  0.64705882, 'Pear')
#  (14, 15,  26.,  38., 'F',  0.68421053, 'Pear')
#  (15, 16,  26.,  37., 'F',  0.7027027 , 'Pear')
#  (16, 17,  25.,  38., 'F',  0.65789474, 'Pear')
#  (17, 18,  26.,  37., 'F',  0.7027027 , 'Pear')
#  (18, 19,  28.,  40., 'F',  0.7       , 'Pear')
#  (19, 20,  23.,  35., 'F',  0.65714286, 'Pear')]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-179a49bc3377> in <module>()
#      25
#      26 # add the two new columns to the dtype descriptor
# ---> 27 dt = np.dtype(data_recarray.dtype.descr + [('W2H Ratio',float),('Shape','U5')])
#      28
#      29 # create a new results array with the same number of data_recarray and the new dtype
#
# ValueError: field 'Shape' occurs more than once

# %% [markdown]
# ## Output

# %%
# Goal: pretty print the rows as an HTML table

# Note: this works, but we can do this much better with pandas
html_table = '<table><tr><th>'
html_table += "</th><th>".join(results.dtype.names)
html_table += '</th></tr>'
for row in results:
    html_table += "<tr><td>"
    html_table += "</td><td>".join(str(v) for v in row)
    html_table += "</td></tr>"
html_table += "</table>"

from IPython.display import HTML, display
display(HTML(html_table))

# Export to "StatsResults.csv"
np.savetxt("StatsResults.csv",results,fmt='%s',delimiter=',',header=','.join(results.dtype.names),comments="")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3cd8bb31803c> in <module>()
#       3 # Note: this works, but we can do this much better with pandas
#       4 html_table = '<table><tr><th>'
# ----> 5 html_table += "</th><th>".join(results.dtype.names)
#       6 html_table += '</th></tr>'
#       7 for row in results:
#
# NameError: name 'results' is not defined
